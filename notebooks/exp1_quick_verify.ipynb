# %% [markdown]
# # 🔬 Experiment 1: Quick Verification
#
# 测试 Gaussian 激活函数在简单 MLP 网络上的表现。
#
# **GitHub:** https://github.com/physics31415926/gaussian-activation

# %%
# Check GPU
# !nvidia-smi

import torch
print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Clone repository
# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git
# %cd gaussian-activation

# %%
# Run Experiment 1
import sys
sys.path.insert(0, '.')

from experiments.quick_verify import main as quick_verify
quick_verify()

# %%
# Download results
from google.colab import files
files.download('results/quick_verify_activations.png')
files.download('results/quick_verify_results.png')
