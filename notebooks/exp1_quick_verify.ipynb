# %% [markdown]
# # 🧪 Experiment 1: Quick Verify
#
# 验证 Gaussian 激活函数基本功能

# %%
# Clone and setup
import os

# !mkdir -p /content/workspace
os.chdir('/content/workspace')

# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git

os.chdir('gaussian-activation')
print(f"Current directory: {os.getcwd()}")

# %%
# Run quick verify
# !python -c "
import torch
from src.activations import LearnableGaussian

# Test
act = LearnableGaussian()
x = torch.randn(10)
y = act(x)
print(f'Input: {x}')
print(f'Output: {y}')
print('✓ LearnableGaussian works!')
"
