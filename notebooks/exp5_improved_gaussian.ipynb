# %% [markdown]
# # 🚀 Experiment 5: Improved Gaussian Activation
#
# 测试改进的 Gaussian 激活函数：
# - **ScaledGaussian**: 添加可学习的缩放因子 gamma 和偏移 beta
# - **GaussianWithResidual**: 添加残差连接，输出 = Gaussian(x) + alpha*x
#
# 解决深层网络中的梯度消失问题。
#
# **GitHub:** https://github.com/physics31415926/gaussian-activation

# %%
# Check GPU
# !nvidia-smi

import torch
print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Clone repository
# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git
# %cd gaussian-activation

# %%
# Run Experiment 5
# !python experiments/exp5_improved_gaussian.py

# %%
# Download results
from google.colab import files
files.download('results/improved_gaussian_comparison.png')
files.download('results/improved_gaussian_bar.png')
