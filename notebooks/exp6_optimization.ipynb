# %% [markdown]
# # 🧪 Experiment 6: Optimization
#
# 综合优化实验：LearnableGaussian vs ReLU

# %%
# Check GPU
# !nvidia-smi

import torch
print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

# %%
# Clone and setup
import os

# !mkdir -p /content/workspace
os.chdir('/content/workspace')

# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git

os.chdir('gaussian-activation')
print(f"Current directory: {os.getcwd()}")

# %%
# Run experiment
# !python experiments/exp6_optimization.py
