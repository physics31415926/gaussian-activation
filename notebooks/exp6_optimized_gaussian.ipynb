# %% [markdown]
# # ⚡ Experiment 6: Optimized Gaussian Activation
#
# 测试三种优化策略：
#
# 1. **初始化策略** - GaussianInit：增大初始权重，使输入落在高响应区
# 2. **参数化改进** - LayerWiseGaussian：每层独立的 μ, σ, γ, β
# 4. **归一化改进** - GroupNorm/LayerNorm：对小 batch size 更稳定
#
# **GitHub:** https://github.com/physics31415926/gaussian-activation

# %%
# Check GPU
# !nvidia-smi

import torch
print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Clone repository
# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git
# %cd gaussian-activation

# %%
# Run Experiment 6
# !python experiments/exp6_optimized_gaussian.py

# %%
# Download results
from google.colab import files
files.download('results/exp6_optimized_comparison.png')
files.download('results/exp6_optimized_bar.png')
