# %% [markdown]
# # 🧪 Experiment 7: Qwen3-0.6B 激活函数替换
#
# 将 Qwen3-0.6B 的激活函数替换为 LearnableGaussian
#
# **目标:**
# - 加载 Qwen3-0.6B 模型
# - 识别并替换所有激活函数层
# - 测试替换后的模型输出
# - 分析 LearnableGaussian 参数分布
#
# **GitHub:** https://github.com/physics31415926/gaussian-activation

# %%
# Check GPU
# !nvidia-smi

import torch
print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %%
# Install dependencies
# !pip install transformers accelerate sentencepiece -q

# %%
# Clone repository
# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git
# %cd gaussian-activation

# %%
# Run Experiment 7
# !python experiments/exp7_qwen3_gaussian.py

# %%
# View results
import json
with open('results/exp7_qwen3_results.json', 'r') as f:
    results = json.load(f)

print("\n" + "="*50)
print("实验结果摘要")
print("="*50)
print(f"模型: {results['model']}")
print(f"替换的激活函数数量: {results['replaced_activations']}")
print(f"模型参数量: {results['total_parameters']:,}")
print(f"LearnableGaussian 层数: {results['gaussian_layers']}")
print("\n原始模型输出:")
print(f"  {results['original_output']}")
print("\n替换后模型输出:")
print(f"  {results['gaussian_output']}")
