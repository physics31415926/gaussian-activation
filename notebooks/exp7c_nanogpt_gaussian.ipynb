# %% [markdown]
# # 🧪 Experiment 7c: nanoGPT + LearnableGaussian
#
# 使用可学习 Gaussian 激活函数，训练后可视化参数变化
#
# ## LearnableGaussian 参数
#
# | 参数 | 说明 | 初始值 |
# |------|------|--------|
# | **mu** | 左右平移 | 0.0 |
# | **sigma** | 宽度 | 1.0 |
# | **gamma** | 缩放 | 1.0 |
# | **beta** | 上下平移 | 0.0 |
#
# **GitHub:** https://github.com/physics31415926/gaussian-activation

# %%
# Check GPU
# !nvidia-smi

import torch
print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Clone and setup
import os

# 创建工作目录并进入
# !mkdir -p /content/workspace
os.chdir('/content/workspace')

# 克隆仓库
# !rm -rf gaussian-activation
# !git clone https://github.com/physics31415926/gaussian-activation.git

# 进入项目目录
os.chdir('gaussian-activation')
print(f"Current directory: {os.getcwd()}")
print(f"Files: {os.listdir('.')}")

# %%
# Verify LearnableGaussian exists
print("Checking src/activations.py...")
# !grep -n "class LearnableGaussian" src/activations.py
print("\n✓ LearnableGaussian class found!")

# %%
# Run Experiment 7c: LearnableGaussian
# !python experiments/exp7c_nanogpt_gaussian.py

# %%
# Display results
from IPython.display import Image, display

print("\n📊 Gaussian Parameters Distribution:")
display(Image('results/exp7c_gaussian_params.png'))

print("\n📊 All Gaussian Activation Shapes:")
display(Image('results/exp7c_gaussian_activations.png'))
